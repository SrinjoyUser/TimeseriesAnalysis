# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df_master = pd.read_csv("Final_Master_Dataset.csv")

# %%
df_master
# Out:
#      Date      Gold_Reservs_USD_mn   Gold_Volume_mn_troy_oz  \
# 0    2000-01                2945.0                11.502339
# 1    2000-02                3104.0                11.502339
# 2    2000-03                2974.0                11.502339
# 3    2000-04                2895.0                11.502339
# 4    2000-05                2851.0                11.502339
# ..       ...                   ...                      ...
# 310  2025-11              106740.0                28.298487
# 311  2025-12              111262.0                28.303688
# 312  2026-01              126904.0                28.303707
# 313  2026-02              131630.0                28.303709
# 314  2026-03              115395.0                28.309308
#
#       Gold_Price[/10gm]   Gold_CPI   USDINR   Repo_Rate   Overall_CPI  \
# 0               4510.75   ---         43.59   ---         ---
# 1               4712.25   ---         43.65   ---         ---
# 2               4541.90   ---         43.64   ---         ---
# 3               4462.06   ---         43.68   ---         ---
# 4               4371.14   ---         44.08   ---         ---
# ..                  ...        ...      ...         ...           ...
# 310           122834.00   408.4       88.84   5.5         197.9
# 311           131322.55   433.9       90.04   5.25        198
# 312           146169.80   ---         90.90   5.25        ---
# 313           154370.40   ---         90.75   5.25        ---
# 314           147395.00   ---         92.82   5.25        ---
#
#       Inflation_YoY   Inflation_MoM   FPI_Net_INR_Crore  \
# 0     ---             ---                         196.5
# 1     ---             ---                        3084.2
# 2     ---             ---                        1198.9
# 3     ---             ---                        2586.7
# 4     ---             ---                         252.9
# ..              ...             ...                 ...
# 310   0.71            0.3                        2836.0
# 311   1.33            0.05                     -38568.0
# 312   2.38            0                        -29240.0
# 313   2.86            0                         37804.0
# 314   3.12            0                       -125736.0
#
#      " ""GDP current prices (Billions of U.S. dollars)"""  \
# 0     468.396                                      ...
# 1     468.396                                      ...
# 2     468.396                                      ...
# 3     468.396                                      ...
# 4     468.396                                      ...
# ..                                                 ...
# 310   3916.312                                     ...
# 311   3916.312                                     ...
# 312   ---                                          ...
# 313   ---                                          ...
# 314   ---                                          ...
#
#      " ""GDP per capita current prices (U.S. dollars per capita)"""  \
# 0     442.751                                      ...
# 1     442.751                                      ...
# 2     442.751                                      ...
# 3     442.751                                      ...
# 4     442.751                                      ...
# ..                                                 ...
# 310   2675.322                                     ...
# 311   2675.322                                     ...
# 312   ---                                          ...
# 313   ---                                          ...
# 314   ---                                          ...
#
#       Real GDP growth (Annual percent change)  \
# 0     3.8
# 1     3.8
# 2     3.8
# 3     3.8
# 4     3.8
# ..                                        ...
# 310   7.6
# 311   7.6
# 312   ---
# 313   ---
# 314   ---
#
#      Remittances received (Personal remittances received current U.S. $)
# 0                                          12883465957
# 1                                          12883465957
# 2                                          12883465957
# 3                                          12883465957
# 4                                          12883465957
# ..                                                 ...
# 310                                                ---
# 311                                                ---
# 312                                                ---
# 313                                                ---
# 314                                                ---
#
# [315 rows x 15 columns]

# %%
df_master.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 315 entries, 0 to 314
# Data columns (total 15 columns):
#  #   Column                                                                Non-Null Count  Dtype
# ---  ------                                                                --------------  -----
#  0   Date                                                                  315 non-null    object
#  1    Gold_Reservs_USD_mn                                                  315 non-null    float64
#  2    Gold_Volume_mn_troy_oz                                               315 non-null    float64
#  3    Gold_Price[/10gm]                                                    315 non-null    float64
#  4    Gold_CPI                                                             315 non-null    object
#  5    USDINR                                                               315 non-null    float64
#  6    Repo_Rate                                                            315 non-null    object
#  7    Overall_CPI                                                          315 non-null    object
#  8    Inflation_YoY                                                        315 non-null    object
#  9    Inflation_MoM                                                        315 non-null    object
#  10   FPI_Net_INR_Crore                                                    315 non-null    float64
#  11   " ""GDP current prices (Billions of U.S. dollars)"""                 315 non-null    object
#  12   " ""GDP per capita current prices (U.S. dollars per capita)"""       315 non-null    object
#  13   Real GDP growth (Annual percent change)                              315 non-null    object
#  14   Remittances received (Personal remittances received current U.S. $)  315 non-null    object
# dtypes: float64(5), object(10)
# memory usage: 37.0+ KB

# %%
df_master.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # **What is Gold Anomaly Detection?**
#
# ![image.png](data:image/png;base64,...)

# %%
df_master.columns = df_master.columns.str.strip()
df_master.columns.tolist()

print(df_master.columns)
# Out:
# Index(['Date', 'Gold_Reservs_USD_mn', 'Gold_Volume_mn_troy_oz',
#        'Gold_Price[/10gm]', 'Gold_CPI', 'USDINR', 'Repo_Rate', 'Overall_CPI',
#        'Inflation_YoY', 'Inflation_MoM', 'FPI_Net_INR_Crore',
#        '" ""GDP current prices (Billions of U.S. dollars)"""',
#        '" ""GDP per capita current prices (U.S. dollars per capita)"""',
#        'Real GDP growth (Annual percent change)',
#        'Remittances received (Personal remittances received current U.S. $)'],
#       dtype='object')

# %%
df_master['Gold_Return_%'] = (
    df_master['Gold_Price[/10gm]']
    .pct_change()
    * 100
)

# %%
df_master
# Out:
#         Date  Gold_Reservs_USD_mn  Gold_Volume_mn_troy_oz  Gold_Price[/10gm]  \
# 0    2000-01               2945.0               11.502339            4510.75
# 1    2000-02               3104.0               11.502339            4712.25
# 2    2000-03               2974.0               11.502339            4541.90
# 3    2000-04               2895.0               11.502339            4462.06
# 4    2000-05               2851.0               11.502339            4371.14
# ..       ...                  ...                     ...                ...
# 310  2025-11             106740.0               28.298487          122834.00
# 311  2025-12             111262.0               28.303688          131322.55
# 312  2026-01             126904.0               28.303707          146169.80
# 313  2026-02             131630.0               28.303709          154370.40
# 314  2026-03             115395.0               28.309308          147395.00
#
#       Gold_CPI  USDINR   Repo_Rate   Overall_CPI   Inflation_YoY  \
# 0     ---        43.59   ---         ---           ---
# 1     ---        43.65   ---         ---           ---
# 2     ---        43.64   ---         ---           ---
# 3     ---        43.68   ---         ---           ---
# 4     ---        44.08   ---         ---           ---
# ..         ...     ...         ...           ...             ...
# 310   408.4      88.84   5.5         197.9         0.71
# 311   433.9      90.04   5.25        198           1.33
# 312   ---        90.90   5.25        ---           2.38
# 313   ---        90.75   5.25        ---           2.86
# 314   ---        92.82   5.25        ---           3.12
#
#       Inflation_MoM  FPI_Net_INR_Crore  \
# 0     ---                        196.5
# 1     ---                       3084.2
# 2     ---                       1198.9
# 3     ---                       2586.7
# 4     ---                        252.9
# ..              ...                ...
# 310   0.3                       2836.0
# 311   0.05                    -38568.0
# 312   0                       -29240.0
# 313   0                        37804.0
# 314   0                      -125736.0
#
#     " ""GDP current prices (Billions of U.S. dollars)"""  \
# 0     468.396                                      ...
# 1     468.396                                      ...
# 2     468.396                                      ...
# 3     468.396                                      ...
# 4     468.396                                      ...
# ..                                                 ...
# 310   3916.312                                     ...
# 311   3916.312                                     ...
# 312   ---                                          ...
# 313   ---                                          ...
# 314   ---                                          ...
#
#     " ""GDP per capita current prices (U.S. dollars per capita)"""  \
# 0     442.751                                      ...
# 1     442.751                                      ...
# 2     442.751                                      ...
# 3     442.751                                      ...
# 4     442.751                                      ...
# ..                                                 ...
# 310   2675.322                                     ...
# 311   2675.322                                     ...
# 312   ---                                          ...
# 313   ---                                          ...
# 314   ---                                          ...
#
#       Real GDP growth (Annual percent change)  \
# 0     3.8
# 1     3.8
# 2     3.8
# 3     3.8
# 4     3.8
# ..                                        ...
# 310   7.6
# 311   7.6
# 312   ---
# 313   ---
# 314   ---
#
#     Remittances received (Personal remittances received current U.S. $)  \
# 0                                          12883465957
# 1                                          12883465957
# 2                                          12883465957
# 3                                          12883465957
# 4                                          12883465957
# ..                                                 ...
# 310                                                ---
# 311                                                ---
# 312                                                ---
# 313                                                ---
# 314                                                ---
#
#      Gold_Return_%
# 0              NaN
# 1         4.467106
# 2        -3.615046
# 3        -1.757855
# 4        -2.037624
# ..             ...
# 310       0.441312
# 311       6.910587
# 312      11.305941
# 313       5.610324
# 314      -4.518612
#
# [315 rows x 16 columns]

# %%
df_master['Gold_Return_%'].describe()
# Out:
# count    314.000000
# mean       1.183587
# std        3.706775
# min      -10.274561
# 25%       -1.156393
# 50%        0.772474
# 75%        3.072742
# max       15.513790
# Name: Gold_Return_%, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(14,7))

sns.histplot(
    data=df_master,
    x='Gold_Return_%',
    bins=35,
    kde=True,
    stat='density',
    alpha=0.7
)

plt.title(
    'Distribution of Monthly Gold Returns (2000–2026)',
    fontsize=16,
    fontweight='bold',
    pad=15
)

plt.xlabel(
    'Monthly Return (%)',
    fontsize=12
)

plt.ylabel(
    'Density',
    fontsize=12
)

plt.grid(
    alpha=0.25,
    linestyle='--'
)

plt.tight_layout()

plt.show()

# %%
mean_return = df_master['Gold_Return_%'].mean()
std_return = df_master['Gold_Return_%'].std()
upper_limit = mean_return + 2*std_return
lower_limit = mean_return - 2*std_return
print(f'Mean Return: {mean_return:.2f}%')
print(f'Standard Deviation: {std_return:.2f}%')
print(f'Upper Limit: {upper_limit:.2f}%')
print(f'Lower Limit: {lower_limit:.2f}%')
# Out:
# Mean Return: 1.18%
# Standard Deviation: 3.71%
# Upper Limit: 8.60%
# Lower Limit: -6.23%

# %%
gold_anomalies = df_master[
    (df_master['Gold_Return_%'] > upper_limit)
    |
    (df_master['Gold_Return_%'] < lower_limit)
]

# %%
gold_anomalies[
    ['Date',
     'Gold_Price[/10gm]',
     'Gold_Return_%']
]
# Out:
#         Date  Gold_Price[/10gm]  Gold_Return_%
# 75   2006-04            8987.06      11.363817
# 76   2006-05            9965.00      10.881645
# 77   2006-06            8941.14     -10.274561
# 96   2008-01           11295.00       9.758337
# 99   2008-04           11814.75      -6.521111
# 103  2008-08           11835.75      -9.122913
# 109  2009-02           14778.68       9.625586
# 139  2011-08           25826.25      14.039542
# 163  2013-08           30178.82      11.895041
# 203  2016-12           28169.05      -7.284333
# 243  2020-04           48723.22      15.513790
# 269  2022-06           46519.23      -8.585500
# 286  2023-11           60827.55       9.961567
# 291  2024-04           71492.50       9.691097
# 308  2025-09          109531.32       9.879120
# 309  2025-10          122294.30      11.652357
# 312  2026-01          146169.80      11.305941

# %%
top_gainers = (
    df_master
    .nlargest(
        15,
        'Gold_Return_%'
    )
)

# %%
top_gainers[
    ['Date',
     'Gold_Return_%']
]
# Out:
#         Date  Gold_Return_%
# 243  2020-04      15.513790
# 139  2011-08      14.039542
# 163  2013-08      11.895041
# 309  2025-10      11.652357
# 75   2006-04      11.363817
# 312  2026-01      11.305941
# 76   2006-05      10.881645
# 286  2023-11       9.961567
# 308  2025-09       9.879120
# 96   2008-01       9.758337
# 291  2024-04       9.691097
# 109  2009-02       9.625586
# 285  2023-10       8.537793
# 124  2010-05       8.255166
# 193  2016-02       7.979267

# %%
top_gainers_plot = (
    top_gainers
    .sort_values('Gold_Return_%')
)


plt.figure(figsize=(10,7))

bars = plt.barh(
    top_gainers_plot['Date'],
    top_gainers_plot['Gold_Return_%'],
    color='forestgreen',
    edgecolor='black'
)

plt.title(
    'Top 15 Monthly Gold Price Surges',
    fontsize=16,
    fontweight='bold'
)

plt.xlabel('Monthly Return (%)')

plt.grid(
    axis='x',
    linestyle='--',
    alpha=0.4
)

for bar in bars:

    width = bar.get_width()

    plt.text(
        width - 0.3,
        bar.get_y() + bar.get_height()/2,
        f'{width:.1f}%',
        va='center',
        ha='right',
        fontsize=9,
        color='white',
        fontweight='bold'
    )

plt.tight_layout()
plt.show()

# %%
top_losers = (
    df_master
    .nsmallest(
        15,
        'Gold_Return_%'
    )
)

# %%
top_losers[
    ['Date',
     'Gold_Return_%']
]
# Out:
#         Date  Gold_Return_%
# 77   2006-06     -10.274561
# 103  2008-08      -9.122913
# 269  2022-06      -8.585500
# 203  2016-12      -7.284333
# 99   2008-04      -6.521111
# 38   2003-03      -6.183450
# 159  2013-04      -6.076123
# 80   2006-09      -5.803660
# 270  2022-07      -5.341554
# 254  2021-03      -5.142425
# 253  2021-02      -4.945598
# 173  2014-06      -4.915409
# 39   2003-04      -4.847187
# 88   2007-05      -4.829972
# 111  2009-04      -4.797502

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(14,6))

bars = plt.bar(
    top_losers['Date'],
    top_losers['Gold_Return_%'],
    color='crimson',
    edgecolor='black'
)

plt.title(
    'Top 15 Worst Monthly Gold Returns',
    fontsize=16,
    fontweight='bold'
)

plt.xlabel('Month')
plt.ylabel('Monthly Return (%)')

plt.xticks(rotation=45)

plt.grid(
    axis='y',
    linestyle='--',
    alpha=0.4
)

# Value labels
for bar in bars:
    height = bar.get_height()

    plt.text(
        bar.get_x() + bar.get_width()/2,
        height - 0.4,
        f'{height:.1f}%',
        ha='center',
        va='top',
        fontsize=9,
        fontweight='bold'
    )

plt.tight_layout()
plt.show()

# %%
df_master['Date'] = pd.to_datetime(df_master['Date'])

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

plt.figure(figsize=(18,6))

plt.plot(
    df_master['Date'],
    df_master['Gold_Return_%'],
    alpha=0.7,
    linewidth=1.5
)

plt.scatter(
    gold_anomalies['Date'],
    gold_anomalies['Gold_Return_%'],
    color='red',
    s=70,
    label='Anomaly'
)

plt.axhline(
    upper_limit,
    linestyle='--',
    color='green',
    label='+2σ Threshold'
)

plt.axhline(
    lower_limit,
    linestyle='--',
    color='darkred',
    label='-2σ Threshold'
)

# Show only years
ax = plt.gca()

ax.xaxis.set_major_locator(
    mdates.YearLocator(2)   # every 2 years
)

ax.xaxis.set_major_formatter(
    mdates.DateFormatter('%Y')
)

plt.xticks(rotation=45)

plt.title(
    'Gold Monthly Return Anomalies (2000–2026)',
    fontsize=16,
    fontweight='bold'
)

plt.ylabel('Monthly Return (%)')
plt.xlabel('Year')

plt.grid(alpha=0.3)

plt.legend()

plt.tight_layout()

plt.show()

# %%
event_analysis = pd.DataFrame({

    'Date': [
        '2006-04',
        '2006-05',
        '2006-06',
        '2008-01',
        '2008-04',
        '2008-08',
        '2009-02',
        '2011-08',
        '2013-08',
        '2016-12',
        '2020-04',
        '2022-06',
        '2023-11',
        '2024-04',
        '2025-09',
        '2025-10',
        '2026-01'
    ],

    'Return_%': [
        11.36,
        10.88,
        -10.27,
        9.76,
        -6.52,
        -9.12,
        9.63,
        14.04,
        11.90,
        -7.28,
        15.51,
        -8.59,
        9.96,
        9.69,
        9.88,
        11.65,
        11.31
    ],

    'Event': [

        'Commodity Rally',
        'Commodity Rally',
        'Profit Booking',

        'Pre-GFC Uncertainty',
        'GFC Volatility Begins',
        'Global Financial Crisis',

        'Flight to Safety',

        'Euro Debt Crisis',
        'Taper Tantrum & INR Crisis',

        'Post US Election & Demonetization',

        'COVID Pandemic',

        'Russia-Ukraine War',

        'Israel-Hamas Conflict',

        'Election Year & Central Bank Buying',

        'Global Gold Rally',
        'Tariff / Geopolitical Tension',
        'Continuation of Safe-Haven Demand'
    ],

    'Economic_Explanation': [

        'Strong global commodity demand pushed precious metal prices higher.',

        'Bullish commodity cycle increased investor interest in gold.',

        'Sharp correction after rapid gains and profit booking by investors.',

        'Investors began moving toward safer assets before the financial crisis intensified.',

        'Financial market instability increased volatility in gold prices.',

        'Global market panic caused large portfolio shifts and abnormal gold movements.',

        'Investors sought safe-haven assets amid financial uncertainty.',

        'European sovereign debt concerns and US credit downgrade boosted gold demand.',

        'Rupee depreciation and taper fears sharply increased domestic gold prices.',

        'Market uncertainty after demonetization and global political events.',

        'Lockdowns, uncertainty, and safe-haven demand drove a historic surge in gold.',

        'War-driven inflation fears and central bank tightening created volatility.',

        'Geopolitical tensions increased demand for safe assets.',

        'Election uncertainty and record central-bank purchases supported gold prices.',

        'Strong global demand and expectations of monetary easing.',

        'Trade/tariff concerns and geopolitical uncertainty increased safe-haven buying.',

        'Continuation of global uncertainty and persistent demand for gold.'
    ]
})

# %%
event_analysis
# Out:
#        Date  Return_%                                Event  \
# 0   2006-04     11.36                      Commodity Rally
# 1   2006-05     10.88                      Commodity Rally
# 2   2006-06    -10.27                       Profit Booking
# 3   2008-01      9.76                  Pre-GFC Uncertainty
# 4   2008-04     -6.52                GFC Volatility Begins
# 5   2008-08     -9.12              Global Financial Crisis
# 6   2009-02      9.63                     Flight to Safety
# 7   2011-08     14.04                     Euro Debt Crisis
# 8   2013-08     11.90           Taper Tantrum & INR Crisis
# 9   2016-12     -7.28    Post US Election & Demonetization
# 10  2020-04     15.51                       COVID Pandemic
# 11  2022-06     -8.59                   Russia-Ukraine War
# 12  2023-11      9.96                Israel-Hamas Conflict
# 13  2024-04      9.69  Election Year & Central Bank Buying
# 14  2025-09      9.88                    Global Gold Rally
# 15  2025-10     11.65        Tariff / Geopolitical Tension
# 16  2026-01     11.31    Continuation of Safe-Haven Demand
#
#                                  Economic_Explanation
# 0   Strong global commodity demand pushed precious...
# 1   Bullish commodity cycle increased investor int...
# 2   Sharp correction after rapid gains and profit ...
# 3   Investors began moving toward safer assets bef...
# 4   Financial market instability increased volatil...
# 5   Global market panic caused large portfolio shi...
# 6   Investors sought safe-haven assets amid financ...
# 7   European sovereign debt concerns and US credit...
# 8   Rupee depreciation and taper fears sharply inc...
# 9   Market uncertainty after demonetization and gl...
# 10  Lockdowns, uncertainty, and safe-haven demand ...
# 11  War-driven inflation fears and central bank ti...
# 12  Geopolitical tensions increased demand for saf...
# 13  Election uncertainty and record central-bank p...
# 14  Strong global demand and expectations of monet...
# 15  Trade/tariff concerns and geopolitical uncerta...
# 16  Continuation of global uncertainty and persist...

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
event_analysis.to_csv(
    "Gold_Anomaly_Event_Analysis.csv",
    index=False
)

# %%
events = {
    '2008-09':'GFC',
    '2011-08':'Euro Crisis',
    '2013-08':'Taper Tantrum',
    '2016-11':'Demonetization',
    '2020-03':'COVID',
    '2022-02':'Ukraine War',
    '2023-10':'Israel-Hamas',
    '2024-06':'Election'
}

# %%
import matplotlib.pyplot as plt
import pandas as pd

df_master['Date'] = pd.to_datetime(df_master['Date'])

plt.figure(figsize=(18,7))

plt.plot(
    df_master['Date'],
    df_master['Gold_Price[/10gm]'],
    linewidth=2.5,
    color='gold'
)

for date,event in events.items():

    plt.axvline(
        pd.to_datetime(date),
        linestyle='--',
        alpha=0.7,
        color='red'
    )

    plt.text(
        pd.to_datetime(date),
        df_master['Gold_Price[/10gm]'].max()*0.85,
        event,
        rotation=90,
        fontsize=9
    )

plt.title(
    'Gold Price Behaviour Around Major Economic and Geopolitical Events (2000–2026)',
    fontsize=16,
    fontweight='bold'
)

plt.xlabel('Year')
plt.ylabel('Gold Price (₹ per 10gm)')

plt.grid(alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Gold During the Modern Crisis Era (2020–2026)**

# %%
df_recent = df_master[
    (df_master['Date'] >= '2020-01')
].copy()

# %%
df_recent
# Out:
#           Date  Gold_Reservs_USD_mn  Gold_Volume_mn_troy_oz  \
# 240 2020-01-01             28997.49               20.414669
# 241 2020-02-01             29896.83               20.634671
# 242 2020-03-01             30578.16               20.994727
# 243 2020-04-01             32277.30               21.054800
# 244 2020-05-01             32897.70               21.144805
# ..         ...                  ...                     ...
# 310 2025-11-01            106740.00               28.298487
# 311 2025-12-01            111262.00               28.303688
# 312 2026-01-01            126904.00               28.303707
# 313 2026-02-01            131630.00               28.303709
# 314 2026-03-01            115395.00               28.309308
#
#      Gold_Price[/10gm]   Gold_CPI  USDINR   Repo_Rate   Overall_CPI  \
# 240           39987.74   135.5      71.28   5.15        150.2
# 241           41174.35   139.4      71.53   5.15        149.1
# 242           42179.57   ---        74.55   4.4         148.6
# 243           48723.22   ---        76.17   4.4         151.4
# 244           48723.22   ---        75.66   4           150.9
# ..                 ...        ...     ...         ...           ...
# 310          122834.00   408.4      88.84   5.5         197.9
# 311          131322.55   433.9      90.04   5.25        198
# 312          146169.80   ---        90.90   5.25        ---
# 313          154370.40   ---        90.75   5.25        ---
# 314          147395.00   ---        92.82   5.25        ---
#
#       Inflation_YoY   Inflation_MoM  FPI_Net_INR_Crore  \
# 240   7.59            -0.13                      957.0
# 241   6.58            -0.73                     8970.0
# 242   5.84            -0.34                  -118203.0
# 243   7.22            1.88                    -14859.0
# 244   6.27            -0.33                    -7356.0
# ..              ...             ...                ...
# 310   0.71            0.3                       2836.0
# 311   1.33            0.05                    -38568.0
# 312   2.38            0                       -29240.0
# 313   2.86            0                        37804.0
# 314   3.12            0                      -125736.0
#
#     " ""GDP current prices (Billions of U.S. dollars)"""  \
# 240   2611.953                                     ...
# 241   2611.953                                     ...
# 242   2611.953                                     ...
# 243   2611.953                                     ...
# 244   2611.953                                     ...
# ..                                                 ...
# 310   3916.312                                     ...
# 311   3916.312                                     ...
# 312   ---                                          ...
# 313   ---                                          ...
# 314   ---                                          ...
#
#     " ""GDP per capita current prices (U.S. dollars per capita)"""  \
# 240   1862.198                                     ...
# 241   1862.198                                     ...
# 242   1862.198                                     ...
# 243   1862.198                                     ...
# 244   1862.198                                     ...
# ..                                                 ...
# 310   2675.322                                     ...
# 311   2675.322                                     ...
# 312   ---                                          ...
# 313   ---                                          ...
# 314   ---                                          ...
#
#       Real GDP growth (Annual percent change)  \
# 240   -5.8
# 241   -5.8
# 242   -5.8
# 243   -5.8
# 244   -5.8
# ..                                        ...
# 310   7.6
# 311   7.6
# 312   ---
# 313   ---
# 314   ---
#
#     Remittances received (Personal remittances received current U.S. $)  \
# 240                                        83149172934
# 241                                        83149172934
# 242                                        83149172934
# 243                                        83149172934
# 244                                        83149172934
# ..                                                 ...
# 310                                                ---
# 311                                                ---
# 312                                                ---
# 313                                                ---
# 314                                                ---
#
#      Gold_Return_%
# 240       3.340204
# 241       2.967435
# 242       2.441374
# 243      15.513790
# 244       0.000000
# ..             ...
# 310       0.441312
# 311       6.910587
# 312      11.305941
# 313       5.610324
# 314      -4.518612
#
# [75 rows x 16 columns]

# %%
plt.figure(figsize=(16,6))

plt.plot(
    df_recent['Date'],
    df_recent['Gold_Price[/10gm]'],
    linewidth=3
)

plt.title(
    'Gold Price Trend (2020-2026)'
)

plt.ylabel('Gold Price (₹/10gm)')

plt.grid(alpha=0.3)

plt.show()

# %%
# %Growth
start_price = df_recent['Gold_Price[/10gm]'].iloc[0]

end_price = df_recent['Gold_Price[/10gm]'].iloc[-1]

growth = (
    (end_price-start_price)
    / start_price
)*100

print(growth)
# Out:
# 268.6004760459081

# %%
# %CAGR
years = 6

cagr = (
    (end_price/start_price)**(1/years)-1
)*100

print(cagr)
# Out:
# 24.287079180544513

# %%
#Monthly returns

df_recent['Return_%'] = (
    df_recent['Gold_Price[/10gm]']
    .pct_change()
    *100
)

# %%
volatility = (
    df_recent['Return_%']
    .std()
)

print(volatility)
# Out:
# 4.311185467532906

# %%
full_vol = (
    df_master['Gold_Return_%']
    .std()
)

recent_vol = (
    df_recent['Return_%']
    .std()
)

# %%
print("Full Volatility is:",full_vol)
print("Recent Volatility is:",recent_vol)
# Out:
# Full Volatility is: 3.706774502506652
# Recent Volatility is: 4.311185467532906

# %%
plt.figure(figsize=(10,5))

sns.histplot(
    df_recent['Return_%'],
    bins=15,
    kde=True
)

plt.title(
    'Distribution of Gold Returns (2020-2026)'
)

plt.show()

# %%
df_recent['Rolling_Volatility'] = (
    df_recent['Return_%']
    .rolling(12)
    .std()
)

# %%
plt.figure(figsize=(16,6))

plt.plot(
    df_recent['Date'],
    df_recent['Rolling_Volatility']
)

plt.title(
    '12-Month Rolling Volatility'
)

plt.show()

# %%
recent = df_master[
    df_master['Date'] >= '2020-01'
].copy()

recent['Year'] = (
    pd.to_datetime(recent['Date'])
    .dt.year
)

year_stats = []

for year,grp in recent.groupby('Year'):

    start = grp['Gold_Price[/10gm]'].iloc[0]
    end = grp['Gold_Price[/10gm]'].iloc[-1]

    yearly_return = (
        (end-start)/start
    )*100

    volatility = (
        grp['Gold_Return_%']
        .std()
    )

    year_stats.append({
        'Year':year,
        'Return_%':yearly_return,
        'Volatility_%':volatility,
        'Avg_Price':grp['Gold_Price[/10gm]'].mean()
    })

year_stats_df = pd.DataFrame(year_stats)

# %%
recent = df_master[
    df_master['Date'] >= '2020-01'
].copy()

recent['Year'] = pd.to_datetime(
    recent['Date']
).dt.year

year_stats = []

for year, grp in recent.groupby('Year'):

    start_price = grp['Gold_Price[/10gm]'].iloc[0]
    end_price = grp['Gold_Price[/10gm]'].iloc[-1]

    annual_return = (
        (end_price - start_price)
        / start_price
    ) * 100

    annual_volatility = (
        grp['Gold_Return_%']
        .std()
    )

    year_stats.append({
        'Year': str(year),
        'Return_%': annual_return,
        'Volatility_%': annual_volatility
    })

year_stats_df = pd.DataFrame(year_stats)

year_stats_df
# Out:
#    Year   Return_%  Volatility_%
# 0  2020  23.735775      5.323164
# 1  2021  -3.375574      2.771880
# 2  2022  -2.580753      4.002626
# 3  2023  27.608536      3.725771
# 4  2024  22.387653      3.394384
# 5  2025  66.987529      3.823857
# 6  2026   0.838203      8.015110

# %%
plt.figure(figsize=(12,6))

colors = [
    '#4E79A7',
    '#F28E2B',
    '#59A14F',
    '#E15759',
    '#76B7B2',
    '#AF7AA1',
    '#EDC948'
]

bars = plt.bar(
    year_stats_df['Year'],
    year_stats_df['Return_%'],
    color=colors,
    edgecolor='black',
    linewidth=1
)

for bar in bars:

    h = bar.get_height()

    plt.text(
        bar.get_x()+bar.get_width()/2,
        h+1 if h>0 else h-2,
        f'{h:.1f}%',
        ha='center',
        fontweight='bold'
    )

plt.axhline(
    0,
    color='black',
    linewidth=1
)

plt.title(
    'Annual Gold Returns (2020–2026)',
    fontsize=18,
    fontweight='bold'
)

plt.ylabel('Return (%)')

plt.grid(
    axis='y',
    alpha=0.3
)

plt.show()

# %%
plt.figure(figsize=(12,6))

bars = plt.bar(
    year_stats_df['Year'],
    year_stats_df['Volatility_%'],
    color='steelblue',
    edgecolor='black'
)

for bar in bars:

    h = bar.get_height()

    plt.text(
        bar.get_x()+bar.get_width()/2,
        h+0.1,
        f'{h:.1f}',
        ha='center',
        fontweight='bold'
    )

plt.title(
    'Annual Gold Volatility (2020–2026)',
    fontsize=18,
    fontweight='bold'
)

plt.ylabel('Volatility (%)')

plt.grid(
    axis='y',
    alpha=0.3
)

plt.show()

# %%
plt.figure(figsize=(10,7))

plt.scatter(
    year_stats_df['Volatility_%'],
    year_stats_df['Return_%'],
    s=400,
    alpha=0.8
)

for _, row in year_stats_df.iterrows():

    plt.annotate(
        row['Year'],
        (
            row['Volatility_%'],
            row['Return_%']
        ),
        fontsize=11,
        fontweight='bold'
    )

plt.xlabel('Volatility (%)')
plt.ylabel('Return (%)')

plt.title(
    'Gold Risk vs Return (2020–2026)',
    fontsize=18,
    fontweight='bold'
)

plt.grid(alpha=0.3)

plt.show()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Missing Values Audit**

# %%
df_master.isna().sum()
# Out:
# Date                                                                   0
# Gold_Reservs_USD_mn                                                    0
# Gold_Volume_mn_troy_oz                                                 0
# Gold_Price[/10gm]                                                      0
# Gold_CPI                                                               0
# USDINR                                                                 0
# Repo_Rate                                                              0
# Overall_CPI                                                            0
# Inflation_YoY                                                          0
# Inflation_MoM                                                          0
# FPI_Net_INR_Crore                                                      0
# " ""GDP current prices (Billions of U.S. dollars)"""                   0
# " ""GDP per capita current prices (U.S. dollars per capita)"""         0
# Real GDP growth (Annual percent change)                                0
# Remittances received (Personal remittances received current U.S. $)    0
# Gold_Return_%                                                          1
# dtype: int64

# %%
(df_master == '---').sum()
# Out:
# Date                                                                   0
# Gold_Reservs_USD_mn                                                    0
# Gold_Volume_mn_troy_oz                                                 0
# Gold_Price[/10gm]                                                      0
# Gold_CPI                                                               0
# USDINR                                                                 0
# Repo_Rate                                                              0
# Overall_CPI                                                            0
# Inflation_YoY                                                          0
# Inflation_MoM                                                          0
# FPI_Net_INR_Crore                                                      0
# " ""GDP current prices (Billions of U.S. dollars)"""                   0
# " ""GDP per capita current prices (U.S. dollars per capita)"""         0
# Real GDP growth (Annual percent change)                                0
# Remittances received (Personal remittances received current U.S. $)    0
# Gold_Return_%                                                          0
# dtype: int64

# %% [markdown]
# # **Univariate Analysis**

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **inflation YoY**

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Ensure Date is datetime
df_master['Date'] = pd.to_datetime(df_master['Date'])

# Ensure there is no leading or trailing spaces in the column Headings
df_master.columns = df_master.columns.str.strip()

# Replace '---' with NaN and convert to float for 'Inflation_YoY'
df_master['Inflation_YoY'] = df_master['Inflation_YoY'].replace('---', np.NaN).astype(float)
# print(df_master['Inflation_YoY'].dtype)

# Sort by date
df_master = df_master.sort_values('Date')

plt.figure(figsize=(14,6))

sns.lineplot(
    data=df_master,
    x='Date',
    y='Inflation_YoY',
    linewidth=2
)

plt.axhline(
    y=df_master['Inflation_YoY'].mean(),
    linestyle='--',
    color='red',
    label=f"Mean Inflation = {df_master['Inflation_YoY'].mean():.2f}%"
)

plt.title(
    'India Inflation (YoY) Trend: 2014–2026',
    fontsize=16,
    weight='bold'
)

plt.xlabel('Year')
plt.ylabel('Inflation YoY (%)')
plt.legend()
plt.grid(alpha=0.3)

plt.tight_layout()
plt.show()
# Out:
# float64

# %%
df_master['Inflation_YoY'] = df_master['Inflation_YoY'].replace('---', np.nan).astype(float)
sns.histplot(
    df_master['Inflation_YoY']
)
# Out:
# <Axes: xlabel='Inflation_YoY', ylabel='Count'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12,3))

sns.boxplot(
    x=df_master['Inflation_YoY'],
    width=0.4,
    color='#4E79A7',
    linewidth=2,
    fliersize=6
)

plt.title(
    'Distribution of Inflation Rate (YoY)',
    fontsize=16,
    fontweight='bold',
    pad=15
)

plt.xlabel(
    'Inflation Rate (%)',
    fontsize=12
)

plt.grid(
    axis='x',
    linestyle='--',
    alpha=0.4
)

plt.tight_layout()
plt.show()

# %%
q1 = df_master['Inflation_YoY'].quantile(0.25).round(3)
median = df_master['Inflation_YoY'].median().round(3)
q3 = df_master['Inflation_YoY'].quantile(0.75).round(3)

print("Lower Quantile is: ",q1,"\nMedian is: ",median, "\nUpper Quantile is: ",q3)
# Out:
# Lower Quantile is:  3.64
# Median is:  4.92
# Upper Quantile is:  5.945

# %%
plt.figure(figsize=(8,6))

sns.regplot(
    data=df_master,
    x='Inflation_YoY',
    y='Gold_Price[/10gm]',
    scatter_kws={'alpha':0.5},
    line_kws={'color':'red'}
)

plt.title(
    'Gold Price vs Inflation',
    fontsize=15,
    fontweight='bold'
)

plt.xlabel('Inflation YoY (%)')
plt.ylabel('Gold Price (₹/10gm)')

plt.show()

# %%
plt.figure(figsize=(8,6))

sns.regplot(
    data=df_master,
    x='Inflation_YoY',
    y='Gold_Return_%',
    scatter_kws={'alpha':0.5},
    line_kws={'color':'orange'}
)

plt.title(
    'Gold_Return_% vs Inflation',
    fontsize=15,
    fontweight='bold'
)

plt.xlabel('Inflation YoY (%)')
plt.ylabel('Gold_Return_%')

plt.show()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np


# Replace '---' with NaN and convert to float for 'Inflation_MoM'
df_master['Inflation_MoM'] = pd.to_numeric(df_master['Inflation_MoM'], errors='coerce')
df_master['Inflation_MoM'].astype(float)

# Remove missing values
df_inf = df_master[
    ['Gold_Return_%', 'Inflation_MoM']
].dropna()

# Correlation
corr = df_inf.corr().iloc[0,1]

# Plot
plt.figure(figsize=(8,6))

sns.regplot(
    data=df_inf,
    x='Inflation_MoM',
    y='Gold_Return_%',
    scatter_kws={'alpha':0.7},
    line_kws={'linewidth':2}
)

plt.text(
    0.05,
    0.95,
    f'Correlation = {corr:.3f}',
    transform=plt.gca().transAxes,
    fontsize=12,
    bbox=dict(facecolor='white')
)

plt.title(
    'Gold Returns vs Inflation (MoM)',
    fontsize=14,
    weight='bold'
)

plt.xlabel('Inflation MoM (%)')
plt.ylabel('Gold Return (%)')

plt.grid(alpha=0.3)

plt.show()

print(f"Correlation = {corr:.3f}")
# Out:
# Correlation = 0.055

# %%
df_master[
    ['Gold_Return_%','Inflation_YoY']
].corr()
# Out:
#                Gold_Return_%  Inflation_YoY
# Gold_Return_%       1.000000      -0.179521
# Inflation_YoY      -0.179521       1.000000

# %%
df_master[
    ['Gold_Price[/10gm]','Inflation_YoY']
].corr()
# Out:
#                    Gold_Price[/10gm]  Inflation_YoY
# Gold_Price[/10gm]           1.000000      -0.336422
# Inflation_YoY              -0.336422       1.000000

# %% [markdown]
# # **USD_INR -- Exchange Rate**

# %%
#USDINR
sns.histplot(df_master['USDINR'], kde=True)
# Out:
# <Axes: xlabel='USDINR', ylabel='Count'>

# %%
plt.figure(figsize=(14,6))

plt.plot(
    df_master['Date'],
    df_master['USDINR']
)

plt.title('USDINR Exchange Rate (2000–2026)')
plt.xlabel('Year')
plt.ylabel('USD/INR')
plt.grid(alpha=0.3)

plt.show()

# %%
plt.figure(figsize=(8,2))

sns.boxplot(
    x=df_master['USDINR']
)

plt.title('USDINR Boxplot')
plt.show()

# %%
df_master['USDINR'].describe()
# Out:
# count    315.000000
# mean      59.354444
# std       14.783175
# min       39.270000
# 25%       45.925000
# 50%       54.980000
# 75%       71.295000
# max       92.820000
# Name: USDINR, dtype: float64

# %%
events = {
    '2008-09':'GFC',
    '2013-08':'Taper Tantrum',
    '2016-11':'Demonetization',
    '2020-03':'COVID',
    '2022-02':'Ukraine War'
}

plt.figure(figsize=(16,6))

plt.plot(
    pd.to_datetime(df_master['Date']),
    df_master['USDINR'],
    linewidth=2.5,
    color='darkblue'
)

for date,label in events.items():

    plt.axvline(
        pd.to_datetime(date),
        color='red',
        linestyle='--',
        alpha=0.6
    )

    plt.text(
        pd.to_datetime(date),
        df_master['USDINR'].max()*0.95,
        label,
        rotation=90
    )

plt.title(
    'USDINR Movement with Major Economic Events',
    fontsize=16,
    fontweight='bold'
)

plt.ylabel('USDINR')

plt.grid(alpha=0.3)

plt.show()

# %%
pre = df_master[
    (df_master['Date'] >= '2000-01')
    & (df_master['Date'] < '2020-01')
]

post = df_master[
    df_master['Date'] >= '2020-01'
]

comparison = pd.DataFrame({
    'Mean':[pre['USDINR'].mean(),
            post['USDINR'].mean()],
    'Std':[pre['USDINR'].std(),
           post['USDINR'].std()],
    'Min':[pre['USDINR'].min(),
           post['USDINR'].min()],
    'Max':[pre['USDINR'].max(),
           post['USDINR'].max()]
},
index=['2000-2019','2020-2026'])

# %%
plt.figure(figsize=(8,5))

bars = plt.bar(
    comparison.index,
    comparison['Mean'],
    color=['#4E79A7','#E15759'],
    edgecolor='black'
)

for bar in bars:

    h = bar.get_height()

    plt.text(
        bar.get_x()+bar.get_width()/2,
        h+0.5,
        f'{h:.2f}',
        ha='center',
        fontweight='bold'
    )

plt.title(
    'Average USDINR: Pre-COVID vs Post-COVID',
    fontsize=15,
    fontweight='bold'
)

plt.ylabel('Average USDINR')

plt.grid(axis='y', alpha=0.3)

plt.show()

# %%
plt.figure(figsize=(8,5))

for i, period in enumerate(comparison.index):

    plt.plot(
        [i,i],
        [comparison.loc[period,'Min'],
         comparison.loc[period,'Max']],
        linewidth=8,
        alpha=0.7
    )

    plt.scatter(
        i,
        comparison.loc[period,'Mean'],
        s=200,
        color='red',
        zorder=5,
        label='Mean' if i==0 else ""
    )

plt.xticks(
    [0,1],
    comparison.index
)

plt.ylabel('USDINR')

plt.title(
    'USDINR Range Comparison\n(Mean shown as Red Dot)',
    fontsize=15,
    fontweight='bold'
)

plt.grid(alpha=0.3)

plt.legend()

plt.show()

# %%
plt.figure(figsize=(8,6))

sns.regplot(
    data=df_master,
    x='USDINR',
    y='Gold_Price[/10gm]'
)

plt.title('Gold Price vs USDINR')
plt.show()

# %%
df_master[
    ['Gold_Price[/10gm]','USDINR']
].corr()
# Out:
#                    Gold_Price[/10gm]    USDINR
# Gold_Price[/10gm]           1.000000  0.873438
# USDINR                      0.873438  1.000000

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Monthly USDINR returns (%)

df_master['USDINR_Return_%'] = (
    df_master['USDINR']
    .pct_change()
    * 100
)

# Check
df_master[['Date','USDINR','USDINR_Return_%']].head()
# Out:
#         Date  USDINR  USDINR_Return_%
# 0 2000-01-01   43.59              NaN
# 1 2000-02-01   43.65         0.137646
# 2 2000-03-01   43.64        -0.022910
# 3 2000-04-01   43.68         0.091659
# 4 2000-05-01   44.08         0.915751

# %%
df_returns = df_master[
    ['Gold_Return_%', 'USDINR_Return_%']
].dropna()

# %%
corr = df_returns.corr().iloc[0,1]

print(f"Correlation = {corr:.3f}")
# Out:
# Correlation = 0.192

# %%
corr = df_returns.corr().iloc[0,1]

plt.figure(figsize=(8,6))

sns.regplot(
    data=df_returns,
    x='USDINR_Return_%',
    y='Gold_Return_%',
    scatter_kws={'alpha':0.7},
    line_kws={'linewidth':2}
)

plt.text(
    0.05,
    0.95,
    f'Correlation = {corr:.3f}',
    transform=plt.gca().transAxes,
    fontsize=12,
    bbox=dict(facecolor='white')
)

plt.title(
    'Gold Returns vs USDINR Returns',
    fontsize=14,
    weight='bold'
)

plt.xlabel('USDINR Return (%)')
plt.ylabel('Gold Return (%)')

plt.grid(alpha=0.3)

plt.show()

# %% [markdown]
# # **Repo Rate**

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Replace '---' with NaN and convert to float for 'Repo_Rate'
df_master['Repo_Rate'] = df_master['Repo_Rate'].astype(str).str.strip().replace('---', np.NaN).astype(float)
# print(df_master['Inflation_MoM'].head())

plt.figure(figsize=(14,6))

sns.lineplot(
    data=df_master,
    x='Date',
    y='Repo_Rate',
    linewidth=2.5
)

plt.title('Repo Rate Trend in India (2000–2026)',
          fontsize=16,
          weight='bold')

plt.xlabel('Year')
plt.ylabel('Repo Rate (%)')

plt.grid(alpha=0.3)

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8,5))

sns.histplot(
    df_master['Repo_Rate'],
    bins=15,
    kde=True
)

plt.title('Distribution of Repo Rate',
          fontsize=14,
          weight='bold')

plt.xlabel('Repo Rate (%)')
plt.ylabel('Frequency')

plt.grid(alpha=0.3)

plt.show()

# %%
plt.figure(figsize=(8,2))

sns.boxplot(
    x=df_master['Repo_Rate']
)

plt.title('Boxplot of Repo Rate',
          fontsize=14,
          weight='bold')

plt.show()

# %%
corr = df_master[
    ['Gold_Price[/10gm]', 'Repo_Rate']
].corr().iloc[0,1]

plt.figure(figsize=(8,6))

sns.regplot(
    data=df_master,
    x='Repo_Rate',
    y='Gold_Price[/10gm]',
    scatter_kws={'alpha':0.6},
    line_kws={'linewidth':2}
)

plt.text(
    0.05,
    0.95,
    f'Correlation = {corr:.3f}',
    transform=plt.gca().transAxes,
    bbox=dict(facecolor='white')
)

plt.title(
    'Gold Price vs Repo Rate',
    fontsize=14,
    weight='bold'
)

plt.show()

# %%
df_repo = df_master[
    ['Gold_Return_%', 'Repo_Rate']
].dropna()

corr = df_repo.corr().iloc[0,1]

plt.figure(figsize=(8,6))

sns.regplot(
    data=df_repo,
    x='Repo_Rate',
    y='Gold_Return_%',
    scatter_kws={'alpha':0.6},
    line_kws={'linewidth':2}
)

plt.text(
    0.05,
    0.95,
    f'Correlation = {corr:.3f}',
    transform=plt.gca().transAxes,
    bbox=dict(facecolor='white')
)

plt.title(
    'Gold Return vs Repo Rate',
    fontsize=14,
    weight='bold'
)

plt.show()

# %% [markdown]
# # **FPI**

# %%
df_master['FPI_Net_INR_Crore'].describe()
# Out:
# count       315.000000
# mean       4788.703810
# std       22736.582557
# min     -125736.000000
# 25%       -2645.000000
# 50%        2677.000000
# 75%       14877.000000
# max       93538.000000
# Name: FPI_Net_INR_Crore, dtype: float64

# %%
plt.figure(figsize=(14,6))

plt.plot(
    df_master['Date'],
    df_master['FPI_Net_INR_Crore'],
    color='navy',
    linewidth=1.5
)

# Positive region (darker green)
plt.fill_between(
    df_master['Date'],
    0,
    df_master['FPI_Net_INR_Crore'],
    where=df_master['FPI_Net_INR_Crore'] >= 0,
    color='forestgreen',
    alpha=0.7,
    interpolate=True,
    label='Net Inflows'
)

# Negative region (darker red)
plt.fill_between(
    df_master['Date'],
    0,
    df_master['FPI_Net_INR_Crore'],
    where=df_master['FPI_Net_INR_Crore'] < 0,
    color='firebrick',
    alpha=0.8,
    interpolate=True,
    label='Net Outflows'
)

plt.axhline(
    y=0,
    color='red',
    linestyle='--',
    linewidth=1
)

plt.title(
    'Monthly Net FPI Flows (2000–2026)',
    fontsize=16,
    weight='bold'
)

plt.xlabel('Year')
plt.ylabel('FPI Net Investment (₹ Crore)')

plt.legend()
plt.grid(alpha=0.3)

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8,5))

sns.histplot(
    df_master['FPI_Net_INR_Crore'],
    bins=25,
    kde=True
)

plt.title('Distribution of Monthly FPI Flows')

plt.show()

# %%
corr = df_master[
    ['Gold_Price[/10gm]',
     'FPI_Net_INR_Crore']
].corr().iloc[0,1]

plt.figure(figsize=(8,6))

sns.regplot(
    data=df_master,
    x='FPI_Net_INR_Crore',
    y='Gold_Price[/10gm]'
)

plt.title(
    f'Gold Price vs FPI\nCorrelation = {corr:.3f}'
)

plt.show()

# %%
df_fpi = df_master[
    ['Gold_Return_%',
     'FPI_Net_INR_Crore']
].dropna()

corr = df_fpi.corr().iloc[0,1]

plt.figure(figsize=(8,6))

sns.regplot(
    data=df_fpi,
    x='FPI_Net_INR_Crore',
    y='Gold_Return_%'
)

plt.title(
    f'Gold Return vs FPI\nCorrelation = {corr:.3f}'
)

plt.show()

# %% [markdown]
# # **Gold Reserve**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(14,6))

sns.lineplot(
    data=df_master,
    x='Date',
    y='Gold_Reservs_USD_mn',
    linewidth=2.5,
    color='goldenrod'
)

plt.fill_between(
    df_master['Date'],
    df_master['Gold_Reservs_USD_mn'],
    color='gold',
    alpha=0.25
)

plt.title(
    'India Gold Reserves (USD Million)',
    fontsize=16,
    weight='bold'
)

plt.xlabel('Year', fontsize=12)
plt.ylabel('Gold Reserves (USD Million)', fontsize=12)

plt.grid(alpha=0.3)

plt.tight_layout()
plt.show()

# %%
df_master['Gold_Reservs_USD_mn'].describe()
# Out:
# count       315.000000
# mean      23261.104943
# std       22057.399171
# min        2695.000000
# 25%        6397.500000
# 50%       20183.200000
# 75%       28130.500000
# max      131630.000000
# Name: Gold_Reservs_USD_mn, dtype: float64

# %%
corr = df_master[
    ['Gold_Price[/10gm]',
     'Gold_Reservs_USD_mn']
].corr().iloc[0,1]

plt.figure(figsize=(8,6))

sns.regplot(
    data=df_master,
    x='Gold_Reservs_USD_mn',
    y='Gold_Price[/10gm]',
    scatter_kws={
        'alpha':0.6,
        's':50
    },
    line_kws={
        'linewidth':2.5,
        'color':'red'
    }
)

plt.text(
    0.05,
    0.95,
    f'Correlation = {corr:.3f}',
    transform=plt.gca().transAxes,
    fontsize=11,
    bbox=dict(facecolor='white')
)

plt.title(
    'Gold Price vs Gold Reserves',
    fontsize=14,
    weight='bold'
)

plt.xlabel('Gold Reserves (USD Million)')
plt.ylabel('Gold Price (₹/10gm)')

plt.grid(alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# # **GDP growth**

# %%
import numpy as np

df_master['Real GDP growth (Annual percent change)'] = (
    df_master['Real GDP growth (Annual percent change)'].astype(str).str.strip()
    .replace('---', np.nan)
    .astype(float)
)

plt.figure(figsize=(14,6))

plt.plot(
    df_master['Date'],
    df_master['Real GDP growth (Annual percent change)'],
    color='teal',
    linewidth=2.5
)

# Positive growth
plt.fill_between(
    df_master['Date'],
    0,
    df_master['Real GDP growth (Annual percent change)'],
    where=df_master['Real GDP growth (Annual percent change)'] >= 0,
    color='mediumseagreen',
    alpha=0.35,
    interpolate=True,
    label='Economic Expansion'
)

# Negative growth
plt.fill_between(
    df_master['Date'],
    0,
    df_master['Real GDP growth (Annual percent change)'],
    where=df_master['Real GDP growth (Annual percent change)'] < 0,
    color='firebrick',
    alpha=0.40,
    interpolate=True,
    label='Economic Contraction'
)

plt.axhline(
    y=0,
    color='black',
    linestyle='--',
    linewidth=1
)

plt.title(
    'India Real GDP Growth (%)',
    fontsize=16,
    weight='bold'
)

plt.xlabel('Year')
plt.ylabel('GDP Growth (%)')

plt.legend()
plt.grid(alpha=0.3)

plt.tight_layout()
plt.show()

# %%
corr = df_master[
    ['Gold_Price[/10gm]',
     'Real GDP growth (Annual percent change)']
].corr().iloc[0,1]

plt.figure(figsize=(8,6))

sns.regplot(
    data=df_master,
    x='Real GDP growth (Annual percent change)',
    y='Gold_Price[/10gm]',
    scatter_kws={'alpha':0.6},
    line_kws={'linewidth':2}
)

plt.text(
    0.05,
    0.95,
    f'Correlation = {corr:.3f}',
    transform=plt.gca().transAxes,
    bbox=dict(facecolor='white')
)

plt.title(
    'Gold Price vs GDP Growth',
    fontsize=14,
    weight='bold'
)

plt.xlabel('GDP Growth (%)')
plt.ylabel('Gold Price (₹/10gm)')

plt.grid(alpha=0.3)

plt.show()

# %%
df_master['" ""GDP per capita current prices (U.S. dollars per capita)"""'] = df_master['" ""GDP per capita current prices (U.S. dollars per capita)"""'].astype(str).str.strip().replace('---',np.NaN).astype(float)

print(df_master['" ""GDP per capita current prices (U.S. dollars per capita)"""'].nunique())
# Out:
# 26

# %%
df_master['" ""GDP per capita current prices (U.S. dollars per capita)"""'] = (df_master['" ""GDP per capita current prices (U.S. dollars per capita)"""'].
                                                                               astype(str).str.strip().replace('---',np.NaN).astype(float))

corr = (df_master[['Gold_Price[/10gm]','" ""GDP per capita current prices (U.S. dollars per capita)"""']].corr().iloc[0,1])

plt.figure(figsize=(8,6))

sns.regplot(data=df_master,\
    x='" ""GDP per capita current prices (U.S. dollars per capita)"""',\
    y='Gold_Price[/10gm]',\
    scatter_kws={'alpha':0.6},\
    line_kws={'linewidth':2}\
)

plt.text(
    0.05,
    0.95,
    f'Correlation = {corr:.3f}',
    transform=plt.gca().transAxes,
    bbox=dict(facecolor='white')
)

plt.title(
    'Gold Price vs GDP Per Capita',
    fontsize=14,
    weight='bold'
)

plt.xlabel('GDP Per Capita (USD)')
plt.ylabel('Gold Price (₹/10gm)')

plt.grid(alpha=0.3)

plt.show()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Remittance**

# %%
df_master['Remittances received (Personal remittances received current U.S. $)'] = pd.to_numeric(df_master['Remittances received (Personal remittances received current U.S. $)'], errors='coerce')

# %%
df_master['Remittances received (Personal remittances received current U.S. $)'].replace('---', np.NaN).astype(float)

plt.figure(figsize=(14,6))

plt.plot(
    df_master['Date'],
    df_master['Remittances received (Personal remittances received current U.S. $)'],
    color='darkgreen',
    linewidth=2.5
)

plt.fill_between(
    df_master['Date'],
    df_master['Remittances received (Personal remittances received current U.S. $)'],
    color='mediumseagreen',
    alpha=0.30
)

plt.title(
    'Remittances Received by India',
    fontsize=16,
    weight='bold'
)

plt.xlabel('Year')
plt.ylabel('Remittances (Current US$)')

plt.grid(alpha=0.3)

plt.tight_layout()
plt.show()

# %%
corr = df_master[
    ['Gold_Price[/10gm]',
     'Remittances received (Personal remittances received current U.S. $)']
].corr().iloc[0,1]

plt.figure(figsize=(8,6))

sns.regplot(
    data=df_master,
    x='Remittances received (Personal remittances received current U.S. $)',
    y='Gold_Price[/10gm]',
    scatter_kws={
        'alpha':0.6,
        's':60
    },
    line_kws={
        'linewidth':2.5,
        'color':'crimson'
    }
)

plt.text(
    0.05,
    0.95,
    f'Correlation = {corr:.3f}',
    transform=plt.gca().transAxes,
    fontsize=11,
    bbox=dict(facecolor='white')
)

plt.title(
    'Gold Price vs Remittances',
    fontsize=14,
    weight='bold'
)

plt.xlabel('Remittances (Current US$)')
plt.ylabel('Gold Price (₹/10gm)')

plt.grid(alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# # **Master Correlation Heatmap**

# %%
df_master.columns
# Out:
# Index(['Date', 'Gold_Reservs_USD_mn', 'Gold_Volume_mn_troy_oz',
#        'Gold_Price[/10gm]', 'Gold_CPI', 'USDINR', 'Repo_Rate', 'Overall_CPI',
#        'Inflation_YoY', 'Inflation_MoM', 'FPI_Net_INR_Crore',
#        '" ""GDP current prices (Billions of U.S. dollars)"""',
#        '" ""GDP per capita current prices (U.S. dollars per capita)"""',
#        'Real GDP growth (Annual percent change)',
#        'Remittances received (Personal remittances received current U.S. $)',
#        'Gold_Return_%', 'USDINR_Return_%'],
#       dtype='object')

# %%
corr_df = df_master[[
    'Gold_Price[/10gm]',
    'USDINR',
    'Inflation_YoY',
    'Repo_Rate',
    'FPI_Net_INR_Crore',
    'Gold_Reservs_USD_mn',
    '" ""GDP per capita current prices (U.S. dollars per capita)"""',
    'Real GDP growth (Annual percent change)',
    'Remittances received (Personal remittances received current U.S. $)'
]].copy()

corr_df.columns = [
    'Gold Price',
    'USDINR',
    'Inflation',
    'Repo Rate',
    'FPI',
    'Gold Reserves',
    'GDP Per Capita',
    'GDP Growth',
    'Remittances'
]
corr = corr_df.corr()

plt.figure(figsize=(10,8))

mask = np.triu(np.ones_like(corr, dtype=bool))

sns.heatmap(
    corr,
    mask=mask,
    annot=True,
    fmt='.2f',
    cmap='coolwarm',
    center=0,
    square=True,
    linewidths=1,
    annot_kws={'size':11},
    cbar_kws={'shrink':0.8}
)

plt.title(
    'Correlation Matrix of Gold Price and Macroeconomic Variables',
    fontsize=16,
    fontweight='bold',
    pad=20
)

plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)

plt.tight_layout()

plt.show()

# %%
plt.figure(figsize=(10,8))

mask = np.triu(np.ones_like(corr, dtype=bool))

sns.heatmap(
    corr,
    mask=mask,
    annot=True,
    fmt='.2f',
    cmap='YlGnBu',
    center=0,
    square=True,
    linewidths=1.5,
    linecolor='white',
    annot_kws={
        'size':11,
        'weight':'bold'
    },
    cbar_kws={
        'shrink':0.8
    }
)

plt.title(
    'Correlation Matrix of Gold Price and Macroeconomic Variables',
    fontsize=18,
    weight='bold',
    pad=20
)

plt.xticks(
    rotation=35,
    ha='right',
    fontsize=11
)

plt.yticks(
    rotation=0,
    fontsize=11
)

plt.tight_layout()
plt.show()
